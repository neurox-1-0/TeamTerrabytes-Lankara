# %% [markdown]
# # 03 — Basket mining (FP-Growth)
#
# Association rules for `POST /basket-mining`.
# When Instacart is unavailable (Kaggle terms), demo co-purchase structure is used.
#
# `python data/scripts/train_analytics_models.py --source demo`

# %%
from pathlib import Path
import subprocess, sys
ROOT = Path.cwd().resolve()
if not (ROOT / "data" / "scripts").exists():
    ROOT = ROOT.parent.parent
subprocess.check_call([sys.executable, str(ROOT / "data/scripts/train_analytics_models.py"), "--source", "demo"])
