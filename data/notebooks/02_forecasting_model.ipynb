# %% [markdown]
# # 02 — Forecasting model (offline)
#
# Per-SKU / category demand forecasts for `POST /forecasting`.
# MAPE-based confidence is stored with the artifact.
#
# Canonical trainer: `python data/scripts/train_analytics_models.py --source demo`

# %%
from pathlib import Path
import subprocess, sys
ROOT = Path.cwd().resolve()
if not (ROOT / "data" / "scripts").exists():
    ROOT = ROOT.parent.parent
subprocess.check_call([sys.executable, str(ROOT / "data/scripts/train_analytics_models.py"), "--source", "demo"])
